# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import pandas as pd
import seaborn as sns

# Teks input
text = """
Long long time ago, in England in Sherwood Forest lived Robin Hood. When he was a boy, he had been cheated by a few noblemen. 
Since then he had decided that he would rob the rich and give what he got to the poor. 
The Sheriff of Nottingham had made an advertisement that he would give many rewards for the capture of Robin Hood, nobody had ever caught him. 
It was because Robin Hood had a number of friends who served him. They acted as informers. 
When the Sheriff had any plan to catch him, they would warn Robin Hood. 
Many rich people were scared of going through Sherwood Forest because they knew that Robin Hood would attack them. 
The Sheriff couldn’t stand it anymore. 
Then he went to ask for the king’s help. However, the king refused to send any of his men to help in the capture of Robin Hood. 
One day The Sheriff and the noblemen held a competition to choose the best shooter in Nottingham. It was for capturing Robin Hood. 
Robin Hood was an excellent shooter. Therefore, Robin Hood would participate in the competition to prove that he was the best. 
He had been warned by his servant, but Robin wasn’t willing to listen. 
The competition began. William, The Sheriff man, and the man in green were trying for the first prize. 
It was time for the last arrow to be shot. The winner of this round would be declared the best shooter in Nottingham. 
William could shot very close to the center. Then the man in green’s turn made the crowd cheer hysterically. 
His arrow went through William’s arrows and the center of the target. 
Then he shot two more arrows towards the chair on which the Sheriff sat. No doubt that the man in green was Robin Hood. 
immediately Robin Hood pulled off his black wig and then jumped over a wall onto his waiting horse and was gone. 
The Sheriff shouted to his men to catch him, but it was too late. Robin Hood escaped successfully.
"""

nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
words = word_tokenize(text.lower())
filtered_words = [word for word in words if word.isalnum() and word not in stop_words]

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(filtered_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

freq_dist = FreqDist(filtered_words)
common_words = freq_dist.most_common(10)
word_freq_df = pd.DataFrame(common_words, columns=['Word', 'Frequency'])
sns.barplot(x='Frequency', y='Word', data=word_freq_df, palette='viridis')
plt.title('Top 10 Most Common Words')
plt.show()

from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()
sentiment_scores = sia.polarity_scores(text)
print("Sentiment Scores:", sentiment_scores)

labels = ['Positive', 'Negative', 'Neutral', 'Compound']
sizes = [sentiment_scores['pos'], sentiment_scores['neg'], sentiment_scores['neu'], sentiment_scores['compound']]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Sentiment Analysis')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhima\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dhima\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# C:\Users\dhima\AppData\Local\Temp\ipykernel_24348\1194062624.py:48: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Frequency', y='Word', data=word_freq_df, palette='viridis')
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dhima\AppData\Roaming\nltk_data...
# Sentiment Scores: {'neg': 0.055, 'neu': 0.826, 'pos': 0.119, 'compound': 0.9806}

# %% [markdown]
# ESSAY
# 1. Bagaimana Memanfaatkan Machine Learning untuk Panggilan API
# Machine Learning dapat digunakan untuk meningkatkan efisiensi dan efektivitas panggilan API dengan beberapa cara:
# a. Prediksi Permintaan API: Dengan menganalisis data permintaan API historis, algoritma machine learning dapat memprediksi kemungkinan permintaan API berhasil atau tidak. Ini dapat membantu mengoptimalkan panggilan API dan mengurangi jumlah permintaan yang gagal.
# b. Optimasi Waktu Respon API: Machine learning dapat digunakan untuk menganalisis waktu respon API dan mengidentifikasi pola untuk mengoptimalkan panggilan API untuk waktu respon yang lebih cepat.
# c. Penanganan Kesalahan API: Algoritma machine learning dapat dilatih untuk mendeteksi dan menangani kesalahan API lebih efektif, mengurangi kebutuhan intervensi manual.
# d. Pembatasan Tingkat API: Dengan menganalisis pola permintaan API, machine learning dapat membantu mengoptimalkan pembatasan tingkat API untuk mencegah panggilan API yang berlebihan dan mengurangi risiko throttling API.
# e. Pengolahan Data API: Machine learning dapat digunakan untuk mengolah dan menganalisis jumlah besar data yang dikembalikan dari panggilan API, mengekstrak wawasan dan pola yang tidak langsung terlihat.
# Untuk memanfaatkan machine learning untuk panggilan API, Anda dapat menggunakan library seperti scikit-learn, TensorFlow, atau PyTorch untuk membangun dan melatih model machine learning. Model-model ini kemudian dapat diintegrasikan dengan library panggilan API seperti requests atau urllib untuk mengoptimalkan panggilan API.
# 2. Apa itu unsupervised learning?
# unsupervised learning adalah jenis machine learning di mana algoritma dilatih pada data yang tidak berlabel, artinya data tidak memiliki variabel target atau respon. Tujuan unsupervised learning adalah untuk mengidentifikasi pola, hubungan, atau struktur dalam data tanpa pengetahuan sebelumnya tentang output yang diharapkan.
# unsupervised learning sering digunakan untuk:
# a. Clustering: Mengelompokkan data serupa berdasarkan karakteristiknya.
# b. Reduksi Dimensi: Mengurangi jumlah fitur atau variabel dalam dataset untuk mengidentifikasi yang paling penting.
# c. Deteksi Anomali: Mengidentifikasi data yang secara signifikan berbeda dari data lainnya.
# d. Estimasi Kepadatan: Mestimasi distribusi dasar data.
# Algoritma unsupervised learning termasuk k-means clustering, hierarchical clustering, principal component analysis (PCA), dan t-SNE.
# 3. Beberapa Alat yang Digunakan untuk Machine Learning
# Berikut adalah beberapa alat populer yang digunakan untuk machine learning:
# a. TensorFlow: Library machine learning open-source yang dikembangkan oleh Google.
# b. PyTorch: Library machine learning open-source yang dikembangkan oleh Facebook.
# c. Scikit-learn: Library machine learning populer untuk Python.
# d. Keras: API neural networks tingkat tinggi yang dapat berjalan di atas TensorFlow, PyTorch, atau Theano.
# e. OpenCV: Library pengolahan citra yang menyediakan model pre-trained dan fungsi untuk pengolahan citra dan video.
# f. NLTK: Library pengolahan bahasa alami untuk pengolahan dan analisis teks.
# g. spaCy: Library pengolahan bahasa alami modern untuk pengolahan dan analisis teks.
# h. H2O: Platform machine learning yang menyediakan kemampuan machine learning dan deep learning otomatis.
# i. Microsoft Azure Machine Learning: Platform machine learning berbasis cloud yang menyediakan kemampuan machine learning dan deep learning otomatis.
# j. Google Cloud AI Platform: Platform machine learning berbasis cloud yang menyediakan kemampuan machine learning dan deep learning otomatis.
